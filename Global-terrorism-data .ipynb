# %%
# import the libraries in python 
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
file_1=pd.read_csv("G:\\Anurag_data_science\\STUDY\Study Material\\semester 1\\EDA\\assignment\\data-society-global-terrorism-data\\original\\gtd_70to91_49566.csv",encoding = 'latin',low_memory = False)

file_2=pd.read_csv("G:\\Anurag_data_science\\STUDY\Study Material\\semester 1\\EDA\\assignment\\data-society-global-terrorism-data\\original\\gtd_92to11_no 93_55072.csv",encoding = 'latin',low_memory = False)

file_3=pd.read_csv("G:\\Anurag_data_science\\STUDY\Study Material\\semester 1\\EDA\\assignment\\data-society-global-terrorism-data\\original\\gtd1993_748.csv",encoding = 'latin',low_memory = False)

file_4=pd.read_csv("G:\\Anurag_data_science\\STUDY\Study Material\\semester 1\\EDA\\assignment\\data-society-global-terrorism-data\\original\\gtd_12to15_52134.csv",encoding = 'latin',low_memory = False)

# %%
final_ls= [file_1,file_2,file_3,file_4]

final_file = pd.concat(final_ls,axis = 0)

# %%
final_file.shape
# Out:
# (157520, 137)

# %%
final_file.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       0     0        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
final_file.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG       float64
# INT_IDEO      float64
# INT_MISC      float64
# INT_ANY       float64
# related        object
# Length: 137, dtype: object

# %%
final_file.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=137)

# %% [markdown]
# # Q.1 How have casualties evolved throughout the years??

# %%
nkill=final_file[['iyear','nkill','nwound']]
nkill = nkill.fillna(0)
nkill=nkill.groupby(['iyear'])[['nkill','nwound']].sum().reset_index()
nkill['Total'] = nkill['nkill'] + nkill['nwound']
nkill.to_csv('Question_1.csv')
nkill
# Out:
#     iyear         nkill    nwound         Total
# 0    1970    171.000000    192.00    363.000000
# 1    1971    173.000000     82.00    255.000000
# 2    1972    566.000000    222.00    788.000000
# 3    1973    370.000000    495.00    865.000000
# 4    1974    542.000000    754.00   1296.000000
# 5    1975    617.000000    617.00   1234.000000
# 6    1976    672.000000    755.00   1427.000000
# 7    1977    456.000000    518.00    974.000000
# 8    1978   1459.000000   1600.00   3059.000000
# 9    1979   2100.000000   2502.00   4602.000000
# 10   1980   4428.000000   3668.00   8096.000000
# 11   1981   4851.000000   3337.00   8188.000000
# 12   1982   5135.000000   3341.00   8476.000000
# 13   1983   9443.000000   4040.00  13483.000000
# 14   1984  10449.000000   5291.00  15740.000000
# 15   1985   7094.000000   5130.00  12224.000000
# 16   1986   5003.000000   5787.00  10790.000000
# 17   1987   6478.000000   5784.00  12262.000000
# 18   1988   7192.000000   6860.00  14052.000000
# ...

# %%
plt.figure(figsize=(20,8))
plt.bar(nkill['iyear'],nkill['nkill'],width=0.5)
plt.xlabel('year')
plt.ylabel('no of people killed')
plt.show()

# %% [markdown]
# # Q.2 Are certain nationalities more targeted? If yes, which one??

# %%
nation = final_file[['natlty1_txt']]
nation = nation.groupby('natlty1_txt').size().reset_index()
nation.loc[0,'natlty1_txt'] = 'Unknown'
nation = nation.rename(columns = {0:'No_of_attack'})
nation.to_csv('Question_2.csv')
nation.sort_values(by = 'No_of_attack',ascending = False)
# Out:
#                             natlty1_txt  No_of_attack
# 87                                 Iraq         18284
# 141                            Pakistan         12326
# 83                                India         10106
# 1                           Afghanistan          8235
# 37                             Colombia          7716
# ..                                  ...           ...
# 207                      Western Sahara             1
# 38   Commonwealth of Independent States             1
# 5                   Antigua and Barbuda             1
# 177                           St. Lucia             1
# 157         Saba (Netherlands Antilles)             1
#
# [213 rows x 2 columns]

# %%
plt.bar(nation['natlty1_txt'],nation['No_of_attack'],width=0.5)
plt.xlabel('nation')
plt.ylabel('no of attack')
plt.rcParams['figure.figsize'] = [25,15]
plt.show()

# %% [markdown]
# # Q.3 Terror attack pattern in United States vs Russian Federation/USSR in last 45 years??

# %%
USvR = final_file[['iyear','country_txt','eventid']]

USvR = USvR[(USvR['country_txt'] == 'United States') | 
            (USvR['country_txt'] == 'Soviet Union') | 
            (USvR['country_txt'] == 'Russia')]
USvR = USvR.groupby(['iyear','country_txt'])['eventid'].count().reset_index()
USvR.to_csv('Question_4.csv')
USvR.head(10)
# Out:
#    iyear    country_txt  eventid
# 0   1970  United States      468
# 1   1971  United States      247
# 2   1972  United States       64
# 3   1973  United States       58
# 4   1974  United States       94
# 5   1975  United States      149
# 6   1976  United States      105
# 7   1977  United States      130
# 8   1978   Soviet Union        1
# 9   1978  United States       87

# %% [markdown]
# # Q.4 Terrorist attack in India and Pakistan in last 45 years??

# %%
IvP = final_file[['iyear','country_txt','eventid']]

IvP = IvP[(IvP['country_txt'] == 'India') | (IvP['country_txt'] == 'Pakistan')]
IvP = IvP.groupby(['iyear','country_txt'])['eventid'].count().reset_index()
IvP.to_csv('Question_5.csv')
IvP.head(10)
# Out:
#    iyear country_txt  eventid
# 0   1970    Pakistan        1
# 1   1972       India        1
# 2   1974    Pakistan        2
# 3   1975       India        1
# 4   1975    Pakistan        2
# 5   1976       India        1
# 6   1976    Pakistan        3
# 7   1977       India        1
# 8   1978    Pakistan        2
# 9   1979       India       20

# %% [markdown]
# # Q.5 Heaviest hit Target types (Based on both Killed and wounded)??

# %%
hit_target = final_file[['targtype1_txt','nkill','nwound']]
hit_target = hit_target.groupby(['targtype1_txt'])[['nkill','nwound']].sum().reset_index()
hit_target['Total'] = hit_target['nkill'] + hit_target['nwound']
hit_target = hit_target.sort_values(by = 'Total',ascending = False)
hit_target.to_csv('Question_6.csv')
hit_target.head()
# Out:
#                   targtype1_txt       nkill      nwound       Total
# 14  Private Citizens & Property  117954.870  136303.150  254258.020
# 10                     Military   87587.680   58886.230  146473.910
# 13                       Police   44660.345   55928.690  100589.035
# 3                      Business   20267.910   48470.215   68738.125
# 7          Government (General)   23419.845   37868.220   61288.065

# %% [markdown]
# # Q.6 Are some countries better at defending themselves against terrorist attacks? If yes, which is the safest country to live??

# %%
nation_attact = final_file.groupby('natlty1_txt')['eventid'].count().reset_index()
nation_attact.head()
# Out:
#    natlty1_txt  eventid
# 0            .     1243
# 1  Afghanistan     8235
# 2      Albania       94
# 3      Algeria     2651
# 4       Angola      422

# %%
nation_kill = final_file.groupby('natlty1_txt')['nkill','nwound'].sum().reset_index()
nation_kill['total'] = nation_kill['nkill'] + nation_kill['nwound']
nation_kill.head()
# Out:
# <ipython-input-16-b1beda25e45c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   nation_kill = final_file.groupby('natlty1_txt')['nkill','nwound'].sum().reset_index()
#    natlty1_txt     nkill    nwound     total
# 0            .   1762.00   1661.00   3423.00
# 1  Afghanistan  24179.33  28941.11  53120.44
# 2      Albania     74.00    120.00    194.00
# 3      Algeria  10919.00   9015.00  19934.00
# 4       Angola   2802.00   2060.00   4862.00

# %%
safest_nation = pd.merge(nation_attact,nation_kill,on='natlty1_txt')
safest_nation.head(10)
# Out:
#            natlty1_txt  eventid     nkill    nwound     total
# 0                    .     1243   1762.00   1661.00   3423.00
# 1          Afghanistan     8235  24179.33  28941.11  53120.44
# 2              Albania       94     74.00    120.00    194.00
# 3              Algeria     2651  10919.00   9015.00  19934.00
# 4               Angola      422   2802.00   2060.00   4862.00
# 5  Antigua and Barbuda        1      0.00      0.00      0.00
# 6            Argentina      640    429.00    514.00    943.00
# 7              Armenia       38     35.00     98.00    133.00
# 8                Asian       19    175.00     32.00    207.00
# 9            Australia      111     79.00    309.00    388.00

# %%
safest_nation['percentage'] = (safest_nation['total']/safest_nation['eventid'])*100
safest_nation = safest_nation.sort_values(by = 'percentage', ascending = True)
safest_nation.to_csv('Question_6.csv')
safest_nation
# Out:
#              natlty1_txt  eventid   nkill  nwound   total    percentage
# 197       United Kingdom        1     0.0     0.0     0.0      0.000000
# 207       Western Sahara        1     0.0     0.0     0.0      0.000000
# 201              Vanuatu        2     0.0     0.0     0.0      0.000000
# 5    Antigua and Barbuda        1     0.0     0.0     0.0      0.000000
# 116         Man, Isle of        1     0.0     0.0     0.0      0.000000
# ..                   ...      ...     ...     ...     ...           ...
# 49              Djibouti       16   258.0    99.0   357.0   2231.250000
# 172          South Sudan       89  1313.0   737.0  2050.0   2303.370787
# 156               Rwanda      141  3367.0   964.0  4331.0   3071.631206
# 34                  Chad       70  1002.0  1594.0  2596.0   3708.571429
# 165            Sinhalese        2   151.0    64.0   215.0  10750.000000
#
# [213 rows x 6 columns]
